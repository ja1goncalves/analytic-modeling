# %% [markdown]
# # Importing Packages

# %%
import numpy as np
import pandas as pd
from datetime import datetime as dt
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller, kpss, acf, grangercausalitytests
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf,month_plot,quarter_plot
from scipy.ndimage.interpolation import shift
from scipy import signal
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style("whitegrid")
plt.rc('xtick', labelsize=15)
plt.rc('ytick', labelsize=15)

# %% [markdown]
# # Importing  and Filtering the Data
# ## Training Data

# %%
dt_parse = lambda dates: dt.strptime(dates, '%Y-%m-%d %H:%M:%S')

data = pd.read_csv('data/transformed/Simples_Geração_de_Energia_Dia_data_norte.csv',
                   header=0, names=['index','value', 'date'], parse_dates=True, index_col='index', date_parser=dt_parse)
data['value'] = data['value'].astype(float)
data['date'] = data['date'].astype('datetime64')
data = data[data['value'] > 0.0]
data['year']  = data['date'].dt.year
data['month'] = data['date'].dt.month
data['day']   = data['date'].dt.day
data['hour'] = data['date'].dt.hour
data['weekday'] = data['date'].dt.weekday
data.head()
# Out:
#                       value                date  year  month  day  hour  \
# index
# 2000-01-01 00:00:00  2422.5 2000-01-01 00:00:00  2000      1    1     0
# 2000-01-01 01:00:00  2769.3 2000-01-01 01:00:00  2000      1    1     1
# 2000-01-01 02:00:00  3124.7 2000-01-01 02:00:00  2000      1    1     2
# 2000-01-01 03:00:00  3154.6 2000-01-01 03:00:00  2000      1    1     3
# 2000-01-01 04:00:00  3121.8 2000-01-01 04:00:00  2000      1    1     4
#
#                      weekday
# index
# 2000-01-01 00:00:00        5
# 2000-01-01 01:00:00        5
# 2000-01-01 02:00:00        5
# 2000-01-01 03:00:00        5
# 2000-01-01 04:00:00        5

# %% [markdown]
# ## Value over times

# %%
plt.plot(data['value'])

# %% [markdown]
# ## Value over times in log with movel media

# %%
v_log = np.log(data['value'])
avg = v_log.rolling(10000).mean()
plt.plot(v_log)
plt.plot(avg, color='red')

# %% [markdown]
# ## Test Data with one hundred first values

# %%
value = data['value'].head(1000)
plt.figure(tight_layout=True)
plt.subplot(211)
value.hist()
plt.title('Density Distribution')
plt.subplot(212)
value.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ## Test Data with all values with another form

# %%
ax = sns.distplot(data['value'], kde=True)
ax.set(xlabel= 'Energia', ylabel='Densidade', title='Energia (MWh)')
plt.show()
# Out:
# /Users/joaomacedo/opt/anaconda3/envs/AnalyticalModeling/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Histogram

# %%
data.hist(grid=True, figsize=(15,12), column=['day', 'weekday', 'month', 'year'])
# Out:
# array([[<AxesSubplot:title={'center':'day'}>,
#         <AxesSubplot:title={'center':'weekday'}>],
#        [<AxesSubplot:title={'center':'month'}>,
#         <AxesSubplot:title={'center':'year'}>]], dtype=object)

# %% [markdown]
# ## Box-plot

# %%
data.boxplot(figsize=(15,10), by='year', column='value')
# Out:
# <AxesSubplot:title={'center':'value'}, xlabel='year'>

# %% [markdown]
# # Transformação ou não das séries: trabalhar com a série original e com a transformada

# %%
data = data.replace([np.inf, -np.inf], np.nan).dropna(axis=0)
value = data['value']

# %%
print(pd.infer_freq(value.index))
# Out:
# None

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries, window_size=10000):
    
    #Determing rolling statistics
    rolmean = timeseries.rolling(window_size).mean()
    rolstd  = timeseries.rolling(window_size).std()

    #Plot rolling statistics:
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
test_stationarity(data['value'])

# %%
#Take first difference:
data_diff = data['value'] - data['value'].shift()
plt.plot(data_diff)

data['value'] = data_diff.values

data = data.replace([np.NaN, np.inf, -np.inf], 346.800)

data
# Out:
#                        value                date  year  month  day  hour  \
# index
# 2000-01-01 00:00:00  346.800 2000-01-01 00:00:00  2000      1    1     0
# 2000-01-01 01:00:00  346.800 2000-01-01 01:00:00  2000      1    1     1
# 2000-01-01 02:00:00  355.400 2000-01-01 02:00:00  2000      1    1     2
# 2000-01-01 03:00:00   29.900 2000-01-01 03:00:00  2000      1    1     3
# 2000-01-01 04:00:00  -32.800 2000-01-01 04:00:00  2000      1    1     4
# ...                      ...                 ...   ...    ...  ...   ...
# 2021-02-11 19:00:00  785.611 2021-02-11 19:00:00  2021      2   11    19
# 2021-02-11 20:00:00   73.685 2021-02-11 20:00:00  2021      2   11    20
# 2021-02-11 21:00:00 -208.682 2021-02-11 21:00:00  2021      2   11    21
# 2021-02-11 22:00:00 -199.585 2021-02-11 22:00:00  2021      2   11    22
# 2021-02-11 23:00:00 -813.585 2021-02-11 23:00:00  2021      2   11    23
#
#                      weekday
# index
# 2000-01-01 00:00:00        5
# 2000-01-01 01:00:00        5
# 2000-01-01 02:00:00        5
# 2000-01-01 03:00:00        5
# 2000-01-01 04:00:00        5
# ...                      ...
# 2021-02-11 19:00:00        3
# 2021-02-11 20:00:00        3
# 2021-02-11 21:00:00        3
# 2021-02-11 22:00:00        3
# 2021-02-11 23:00:00        3
#
# [185069 rows x 7 columns]

# %%
test_stationarity(data['value'])

# %% [markdown]
# # Decomposição da série (Aditivo e Multiplicativo)

# %%
data
# Out:
#                        value                date  year  month  day  hour  \
# index
# 2000-01-01 00:00:00  346.800 2000-01-01 00:00:00  2000      1    1     0
# 2000-01-01 01:00:00  346.800 2000-01-01 01:00:00  2000      1    1     1
# 2000-01-01 02:00:00  355.400 2000-01-01 02:00:00  2000      1    1     2
# 2000-01-01 03:00:00   29.900 2000-01-01 03:00:00  2000      1    1     3
# 2000-01-01 04:00:00  -32.800 2000-01-01 04:00:00  2000      1    1     4
# ...                      ...                 ...   ...    ...  ...   ...
# 2021-02-11 19:00:00  785.611 2021-02-11 19:00:00  2021      2   11    19
# 2021-02-11 20:00:00   73.685 2021-02-11 20:00:00  2021      2   11    20
# 2021-02-11 21:00:00 -208.682 2021-02-11 21:00:00  2021      2   11    21
# 2021-02-11 22:00:00 -199.585 2021-02-11 22:00:00  2021      2   11    22
# 2021-02-11 23:00:00 -813.585 2021-02-11 23:00:00  2021      2   11    23
#
#                      weekday
# index
# 2000-01-01 00:00:00        5
# 2000-01-01 01:00:00        5
# 2000-01-01 02:00:00        5
# 2000-01-01 03:00:00        5
# 2000-01-01 04:00:00        5
# ...                      ...
# 2021-02-11 19:00:00        3
# 2021-02-11 20:00:00        3
# 2021-02-11 21:00:00        3
# 2021-02-11 22:00:00        3
# 2021-02-11 23:00:00        3
#
# [185069 rows x 7 columns]

# %%
data.sort_index(inplace=True)

data.drop(['date', 'year', 'month', 'day', 'hour', 'weekday'],inplace=True,axis=1)

# %%
data.value
# Out:
# index
# 2000-01-01 00:00:00    346.800
# 2000-01-01 01:00:00    346.800
# 2000-01-01 02:00:00    355.400
# 2000-01-01 03:00:00     29.900
# 2000-01-01 04:00:00    -32.800
#                         ...
# 2021-02-11 19:00:00    785.611
# 2021-02-11 20:00:00     73.685
# 2021-02-11 21:00:00   -208.682
# 2021-02-11 22:00:00   -199.585
# 2021-02-11 23:00:00   -813.585
# Name: value, Length: 185069, dtype: float64

# %%
decomposition = sm.tsa.seasonal_decompose(data.value.asfreq('m'), model='additive')
plt.rcParams["figure.figsize"] = [16,9]
fig = decomposition.plot()

# %% [markdown]
# # Teste Dickey Fuller aumentado, KPSS, PP

# %%
def dickey_fuller(timeseries):
    #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)
# Out:
#   File "<ipython-input-1-a2e0a8067b52>", line 3
#     print()'Results of Dickey-Fuller Test:')
#                                           ^
# SyntaxError: invalid syntax
